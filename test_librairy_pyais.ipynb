# %%
import time, csv
import pandas as pd
from pyais import decode, IterMessages
from pyais.stream import FileReaderStream
from pyais.messages import MessageType1
from  collections import defaultdict as ddict
from pyais.stream import TCPConnection
from contextlib import ExitStack

# %%
decoded = decode(b"!AIVDM,1,1,,B,15NG6V0P01G?cFhE`R2IU?wn28R>,0*05")
print(decoded)
# Out:
# MessageType1(msg_type=1, repeat=0, mmsi=367380120, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.1, accuracy=False, lon=-122.404333, lat=37.806948, course=245.2, heading=511, second=59, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=34958)

# %%
parts = [
    b"!AIVDM,2,1,4,A,55O0W7`00001L@gCWGA2uItLth@DqtL5@F22220j1h742t0Ht0000000,0*08",
    b"!AIVDM,2,2,4,A,000000000000000,2*20",
]

# Decode a multipart message using decode
decoded = decode(*parts)
as_dict = decoded.asdict()
print(as_dict)
# Out:
# {'msg_type': 5, 'repeat': 0, 'mmsi': 368060190, 'ais_version': 2, 'imo': 0, 'callsign': 'WDK4954', 'shipname': 'P/V_GOLDEN_GATE', 'ship_type': <ShipType.PilotVessel: 50>, 'to_bow': 14, 'to_stern': 7, 'to_port': 4, 'to_starboard': 2, 'epfd': <EpfdType.Internal_GNSS: 15>, 'month': 0, 'day': 0, 'hour': 24, 'minute': 60, 'draught': 0.0, 'destination': '', 'dte': False, 'spare_1': b'\x00'}

# %%
fake_stream = [
    b"!AIVDM,1,1,,A,13HOI:0P0000VOHLCnHQKwvL05Ip,0*23",
    b"!AIVDM,1,1,,A,133sVfPP00PD>hRMDH@jNOvN20S8,0*7F",
    b"!AIVDM,1,1,,B,100h00PP0@PHFV`Mg5gTH?vNPUIp,0*3B",
    b"!AIVDM,2,1,4,A,55O0W7`00001L@gCWGA2uItLth@DqtL5@F22220j1h742t0Ht0000000,0*08",
    b"!AIVDM,2,2,4,A,000000000000000,2*20",
    b"!AIVDM,1,1,,B,13eaJF0P00Qd388Eew6aagvH85Ip,0*45",
    b"!AIVDM,1,1,,A,14eGrSPP00ncMJTO5C6aBwvP2D0?,0*7A",
    b"!AIVDM,1,1,,A,15MrVH0000KH<:V:NtBLoqFP2H9:,0*2F",
]
for i, msg in enumerate(IterMessages(fake_stream)):
    print(i)
    print(msg.decode())
# Out:
# 0
# MessageType1(msg_type=1, repeat=0, mmsi=227006760, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=False, lon=0.13138, lat=49.475577, course=36.7, heading=511, second=14, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=22136)
# 1
# MessageType1(msg_type=1, repeat=0, mmsi=205448890, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=True, lon=4.419442, lat=51.237658, course=63.3, heading=511, second=15, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=2248)
# 2
# MessageType1(msg_type=1, repeat=0, mmsi=786434, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=1.6, accuracy=True, lon=5.320033, lat=51.967037, course=112.0, heading=511, second=15, maneuver=<ManeuverIndicator.NoSpecialManeuver: 1>, spare_1=b'\x00', raim=False, radio=153208)
# 3
# MessageType5(msg_type=5, repeat=0, mmsi=368060190, ais_version=2, imo=0, callsign='WDK4954', shipname='P/V_GOLDEN_GATE', ship_type=<ShipType.PilotVessel: 50>, to_bow=14, to_stern=7, to_port=4, to_starboard=2, epfd=<EpfdType.Internal_GNSS: 15>, month=0, day=0, hour=24, minute=60, draught=0.0, destination='', dte=False, spare_1=b'\x00')
# 4
# MessageType1(msg_type=1, repeat=0, mmsi=249191000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=True, lon=23.603633, lat=37.955883, course=247.0, heading=511, second=12, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'@', raim=False, radio=22136)
# 5
# MessageType1(msg_type=1, repeat=0, mmsi=316013198, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=True, lon=-130.316237, lat=54.32111, course=237.9, heading=511, second=16, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=81935)
# 6
# MessageType1(msg_type=1, repeat=0, mmsi=366913120, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=False, lon=-64.620662, lat=18.321188, course=329.5, heading=299, second=16, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=98890)

# %% [markdown]
# # Read from a test file:

# %%
filepath = "data/nmea_data_sample.txt"

found = ddict(bool)
i = 0
with FileReaderStream(filepath) as stream:
    for msg in stream:
        decoded = msg.decode()
        if not found[decoded.msg_type]:
            print("msg type: ",decoded.asdict()['msg_type'], list(decoded.asdict().keys()))
            found[decoded.msg_type] = True
        if i == 1000:
            break
        i += 1
# Out:
# msg type:  3 ['msg_type', 'repeat', 'mmsi', 'status', 'turn', 'speed', 'accuracy', 'lon', 'lat', 'course', 'heading', 'second', 'maneuver', 'spare_1', 'raim', 'radio']
# msg type:  1 ['msg_type', 'repeat', 'mmsi', 'status', 'turn', 'speed', 'accuracy', 'lon', 'lat', 'course', 'heading', 'second', 'maneuver', 'spare_1', 'raim', 'radio']
# msg type:  18 ['msg_type', 'repeat', 'mmsi', 'reserved_1', 'speed', 'accuracy', 'lon', 'lat', 'course', 'heading', 'second', 'reserved_2', 'cs', 'display', 'dsc', 'band', 'msg22', 'assigned', 'raim', 'radio']
# msg type:  4 ['msg_type', 'repeat', 'mmsi', 'year', 'month', 'day', 'hour', 'minute', 'second', 'accuracy', 'lon', 'lat', 'epfd', 'spare_1', 'raim', 'radio']
# msg type:  15 ['msg_type', 'repeat', 'mmsi', 'spare_1', 'mmsi1', 'type1_1', 'offset1_1', 'spare_2', 'type1_2', 'offset1_2', 'spare_3', 'mmsi2', 'type2_1', 'offset2_1', 'spare_4']
# msg type:  24 ['msg_type', 'repeat', 'mmsi', 'partno', 'shipname', 'spare_1']
# msg type:  20 ['msg_type', 'repeat', 'mmsi', 'spare_1', 'offset1', 'number1', 'timeout1', 'increment1', 'offset2', 'number2', 'timeout2', 'increment2', 'offset3', 'number3', 'timeout3', 'increment3', 'offset4', 'number4', 'timeout4', 'increment4']

# %% [markdown]
# # Testing Live AIS feed from the Norvegian Coastal Administration

# %%
host = '153.44.253.27'
port = 5631
start = time.time()

for msg in TCPConnection(host, port=port):
    decoded_message = msg.decode()
    ais_content = decoded_message

    print('*' * 80)
    if msg.tag_block:
        # decode & print the tag block if it is available
        msg.tag_block.init()
        print(msg.tag_block.asdict())

    print(ais_content)
    if time.time() > start + 20:  # Print the feed for 20 second
        break
# Out:
# ********************************************************************************
# {'raw': b's:2573335,c:1732120732*08', 'receiver_timestamp': '1732120732', 'source_station': '2573335', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=258019240, partno=0, shipname='FROYBRAND', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573415,c:1732120732*0D', 'receiver_timestamp': '1732120732', 'source_station': '2573415', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257714500, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=8.6, accuracy=True, lon=13.12606, lat=66.67426, course=14.1, heading=26, second=50, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=34751)
# ********************************************************************************
# {'raw': b's:2573305,c:1732120732*0B', 'receiver_timestamp': '1732120732', 'source_station': '2573305', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=259107000, status=<NavigationStatus.EngagedInFishing: 7>, turn=0.0, speed=0.0, accuracy=True, lon=6.90868, lat=62.813767, course=10.4, heading=94, second=56, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=34753)
# ********************************************************************************
# {'raw': b's:2573345,c:1732120733*0E', 'receiver_timestamp': '1732120733', 'source_station': '2573345', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=258829000, status=<NavigationStatus.AtAnchor: 1>, turn=0.0, speed=0.0, accuracy=True, lon=10.685792, lat=64.844665, course=154.8, heading=111, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=0)
# ********************************************************************************
# MessageType1(msg_type=1, repeat=0, mmsi=257706900, status=<NavigationStatus.NotUnderCommand: 2>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=False, lon=5.989728, lat=59.448633, course=360.0, heading=511, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=81931)
# ********************************************************************************
# {'raw': b's:2573405,c:1732120733*0D', 'receiver_timestamp': '1732120733', 'source_station': '2573405', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=109080418, reserved_1=0, speed=2.0, accuracy=True, lon=11.940938, lat=66.362692, course=138.5, heading=511, second=60, reserved_2=0, cs=True, display=False, dsc=False, band=False, msg22=False, assigned=False, raim=False, radio=917510)
# ********************************************************************************
# {'raw': b's:2573465,c:1732120733*0B', 'receiver_timestamp': '1732120733', 'source_station': '2573465', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257595600, status=<NavigationStatus.EngagedInFishing: 7>, turn=0.0, speed=2.5, accuracy=True, lon=13.554965, lat=68.953753, course=22.2, heading=37, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=114696)
# ********************************************************************************
# {'raw': b's:2573505,c:1732120733*0C', 'receiver_timestamp': '1732120733', 'source_station': '2573505', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=257011100, partno=1, ship_type=33, vendorid='SMT', model=1, serial=813483, callsign='LH2030', to_bow=3, to_stern=10, to_port=3, to_starboard=3, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573415,c:1732120733*0C', 'receiver_timestamp': '1732120733', 'source_station': '2573415', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=257603800, ais_version=2, imo=0, callsign='LK9843', shipname='VARDSKAER II', ship_type=<ShipType.Cargo: 70>, to_bow=3, to_stern=10, to_port=4, to_starboard=3, epfd=<EpfdType.GPS: 1>, month=0, day=0, hour=0, minute=0, draught=0.0, destination='LOVUNDLAKS', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573270,c:1732120733*09', 'receiver_timestamp': '1732120733', 'source_station': '2573270', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=259032540, reserved_1=0, speed=0.0, accuracy=False, lon=6.201305, lat=61.781327, course=360.0, heading=511, second=52, reserved_2=0, cs=False, display=False, dsc=True, band=True, msg22=True, assigned=False, raim=False, radio=610042)
# ********************************************************************************
# {'raw': b's:2573555,c:1732120733*09', 'receiver_timestamp': '1732120733', 'source_station': '2573555', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=109050921, partno=1, ship_type=0, vendorid='RS', model=0, serial=1, callsign='', to_bow=0, to_stern=0, to_port=0, to_starboard=0, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573415,c:1732120733*0C', 'receiver_timestamp': '1732120733', 'source_station': '2573415', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=109080418, partno=0, shipname='TROLLFJELL 3', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573110,c:1732120733*0C', 'receiver_timestamp': '1732120733', 'source_station': '2573110', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=258002290, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=True, lon=10.951865, lat=59.20608, course=309.0, heading=45, second=50, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=34760)
# ********************************************************************************
# {'raw': b's:2573315,c:1732120733*0B', 'receiver_timestamp': '1732120733', 'source_station': '2573315', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=246244000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=9.9, accuracy=False, lon=7.571098, lat=63.251185, course=80.9, heading=85, second=51, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=100298)
# ********************************************************************************
# {'raw': b's:2573415,c:1732120733*0C', 'receiver_timestamp': '1732120733', 'source_station': '2573415', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=109080418, partno=1, ship_type=0, vendorid='RS', model=0, serial=15, callsign='', to_bow=0, to_stern=0, to_port=0, to_starboard=0, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573345,c:1732120733*0E', 'receiver_timestamp': '1732120733', 'source_station': '2573345', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257060720, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=False, lon=11.3639, lat=64.683873, course=0.0, heading=324, second=50, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=114756)
# ********************************************************************************
# {'raw': b's:2573305,c:1732120733*0A', 'receiver_timestamp': '1732120733', 'source_station': '2573305', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257010310, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=True, lon=5.91596, lat=62.186573, course=334.1, heading=511, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=49164)
# ********************************************************************************
# {'raw': b's:2573555,c:1732120733*09', 'receiver_timestamp': '1732120733', 'source_station': '2573555', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=109050523, partno=0, shipname='AARVIKSAND BUO [49%]', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573555,c:1732120733*09', 'receiver_timestamp': '1732120733', 'source_station': '2573555', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=109050523, partno=1, ship_type=0, vendorid='RS', model=0, serial=100, callsign='', to_bow=0, to_stern=0, to_port=0, to_starboard=0, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573455,c:1732120733*08', 'receiver_timestamp': '1732120733', 'source_station': '2573455', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=258024810, status=<NavigationStatus.Moored: 5>, turn=-5.0, speed=0.0, accuracy=True, lon=16.901973, lat=68.350973, course=250.3, heading=251, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=85098)
# ********************************************************************************
# {'raw': b's:2573345,c:1732120733*0E', 'receiver_timestamp': '1732120733', 'source_station': '2573345', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257931600, status=<NavigationStatus.UnderWaySailing: 8>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=True, lon=11.576978, lat=64.82324, course=360.0, heading=511, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=49183)
# ********************************************************************************
# {'raw': b's:2573205,c:1732120733*0B', 'receiver_timestamp': '1732120733', 'source_station': '2573205', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=538001388, ais_version=0, imo=7390143, callsign='V7BW9', shipname='GULF ENERGY', ship_type=<ShipType.Tanker: 80>, to_bow=245, to_stern=40, to_port=25, to_starboard=19, epfd=<EpfdType.GPS: 1>, month=1, day=1, hour=9, minute=0, draught=6.5, destination='HAUGESUND', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573315,c:1732120733*0B', 'receiver_timestamp': '1732120733', 'source_station': '2573315', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257527800, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=False, lon=8.211428, lat=63.14465, course=330.0, heading=354, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=114769)
# ********************************************************************************
# {'raw': b's:2573236,c:1732120733*0B', 'receiver_timestamp': '1732120733', 'source_station': '2573236', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType21(msg_type=21, repeat=1, mmsi=992576422, aid_type=<NavAid.DEFAULT: 0>, name='CLOSED AREA', accuracy=True, lon=5.441233, lat=59.233627, to_bow=0, to_stern=0, to_port=0, to_starboard=0, epfd=<EpfdType.Undefined: 0>, second=52, off_position=False, reserved_1=0, raim=False, virtual_aid=True, assigned=True, spare_1=b'\x00', name_ext=None)
# ********************************************************************************
# {'raw': b's:2573115,c:1732120733*09', 'receiver_timestamp': '1732120733', 'source_station': '2573115', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=257369500, status=<NavigationStatus.Moored: 5>, turn=0.0, speed=0.0, accuracy=False, lon=11.074878, lat=59.268187, course=277.0, heading=267, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=82714)
# ********************************************************************************
# {'raw': b's:2573335,c:1732120733*09', 'receiver_timestamp': '1732120733', 'source_station': '2573335', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=258230000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=102.3, accuracy=True, lon=8.804285, lat=63.638527, course=360.0, heading=511, second=40, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=24728)
# ********************************************************************************
# {'raw': b's:2573485,c:1732120733*05', 'receiver_timestamp': '1732120733', 'source_station': '2573485', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257246500, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=False, lon=16.133645, lat=69.323712, course=255.1, heading=15, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=24728)
# ********************************************************************************
# {'raw': b's:2573305,c:1732120733*0A', 'receiver_timestamp': '1732120733', 'source_station': '2573305', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=258220500, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=False, lon=6.333282, lat=62.374663, course=274.6, heading=285, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=49239)
# ********************************************************************************
# {'raw': b's:2573315,c:1732120733*0B', 'receiver_timestamp': '1732120733', 'source_station': '2573315', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=257394500, ais_version=0, imo=7728481, callsign='LGVG', shipname='GRIMM', ship_type=<ShipType.DivingOps: 34>, to_bow=25, to_stern=7, to_port=1, to_starboard=7, epfd=<EpfdType.GPS: 1>, month=3, day=21, hour=12, minute=34, draught=2.5, destination='A', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573560,c:1732120733*0F', 'receiver_timestamp': '1732120733', 'source_station': '2573560', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257011700, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=-3.0, speed=0.0, accuracy=False, lon=23.394583, lat=70.246417, course=172.0, heading=84, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'@', raim=False, radio=34783)
# ********************************************************************************
# {'raw': b's:2573575,c:1732120733*0B', 'receiver_timestamp': '1732120733', 'source_station': '2573575', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=109060460, reserved_1=0, speed=1.5, accuracy=True, lon=28.17344, lat=71.200865, course=151.5, heading=511, second=60, reserved_2=0, cs=True, display=False, dsc=False, band=False, msg22=False, assigned=False, raim=False, radio=917510)
# ********************************************************************************
# {'raw': b's:2573555,c:1732120733*09', 'receiver_timestamp': '1732120733', 'source_station': '2573555', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=109050510, reserved_1=0, speed=1.4, accuracy=True, lon=20.874593, lat=70.192, course=218.7, heading=511, second=60, reserved_2=0, cs=True, display=False, dsc=False, band=False, msg22=False, assigned=False, raim=False, radio=917510)
# ********************************************************************************
# {'raw': b's:2573585,c:1732120733*04', 'receiver_timestamp': '1732120733', 'source_station': '2573585', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=109060460, partno=0, shipname='ROWENTA BOUY', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573555,c:1732120733*09', 'receiver_timestamp': '1732120733', 'source_station': '2573555', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=109050510, partno=0, shipname='ARVIKSAND BOUY [75%]', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573585,c:1732120733*04', 'receiver_timestamp': '1732120733', 'source_station': '2573585', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=109060460, partno=1, ship_type=0, vendorid='RS', model=0, serial=92, callsign='', to_bow=0, to_stern=0, to_port=0, to_starboard=0, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573310,c:1732120733*0E', 'receiver_timestamp': '1732120733', 'source_station': '2573310', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=257904900, ais_version=0, imo=0, callsign='LF3941', shipname='RESCUE GIDEON', ship_type=<ShipType.SearchAndRescueVessel: 51>, to_bow=5, to_stern=8, to_port=2, to_starboard=2, epfd=<EpfdType.GPS: 1>, month=1, day=1, hour=23, minute=59, draught=0.0, destination='91679628', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573555,c:1732120734*0E', 'receiver_timestamp': '1732120734', 'source_station': '2573555', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=109080580, partno=0, shipname='SANTOS BUOY 3', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573515,c:1732120734*0A', 'receiver_timestamp': '1732120734', 'source_station': '2573515', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=259350000, status=<NavigationStatus.Undefined: 15>, turn=0.0, speed=7.5, accuracy=True, lon=19.052395, lat=69.705727, course=23.0, heading=24, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=67563)
# ********************************************************************************
# {'raw': b's:2573555,c:1732120734*0E', 'receiver_timestamp': '1732120734', 'source_station': '2573555', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=109080580, partno=1, ship_type=0, vendorid='RS', model=0, serial=100, callsign='BO12345', to_bow=0, to_stern=0, to_port=0, to_starboard=0, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573213,c:1732120734*0B', 'receiver_timestamp': '1732120734', 'source_station': '2573213', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=255801980, ais_version=1, imo=9648697, callsign='CQOK', shipname='DINA STAR', ship_type=<ShipType.OtherType: 90>, to_bow=19, to_stern=75, to_port=14, to_starboard=6, epfd=<EpfdType.GPS: 1>, month=11, day=14, hour=9, minute=0, draught=6.1, destination='KILLINGOY', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573145,c:1732120734*0B', 'receiver_timestamp': '1732120734', 'source_station': '2573145', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=258304500, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=True, lon=6.635793, lat=58.207367, course=329.3, heading=511, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=24728)
# ********************************************************************************
# {'raw': b's:2573210,c:1732120734*08', 'receiver_timestamp': '1732120734', 'source_station': '2573210', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=212253000, status=<NavigationStatus.Moored: 5>, turn=0.0, speed=0.0, accuracy=True, lon=5.271767, lat=59.395728, course=139.0, heading=139, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=84666)
# ********************************************************************************
# {'raw': b's:2573105,c:1732120734*0F', 'receiver_timestamp': '1732120734', 'source_station': '2573105', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257089530, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=False, lon=10.452425, lat=59.082, course=305.0, heading=79, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=49171)
# ********************************************************************************
# {'raw': b's:2573110,c:1732120734*0B', 'receiver_timestamp': '1732120734', 'source_station': '2573110', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=258055000, ais_version=0, imo=9366122, callsign='LASN8', shipname='SEA CARRIER', ship_type=<ShipType.Cargo: 70>, to_bow=95, to_stern=12, to_port=5, to_starboard=13, epfd=<EpfdType.GPS: 1>, month=11, day=20, hour=8, minute=0, draught=8.4, destination='NOFRK', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573599,c:1732120734*0E', 'receiver_timestamp': '1732120734', 'source_station': '2573599', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=273610340, status=<NavigationStatus.Moored: 5>, turn=0.0, speed=0.0, accuracy=False, lon=30.06412, lat=69.729548, course=198.8, heading=109, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=0)
# ********************************************************************************
# {'raw': b's:2573135,c:1732120734*0C', 'receiver_timestamp': '1732120734', 'source_station': '2573135', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=244150648, ais_version=2, imo=9772606, callsign='PCTZ', shipname='ARKLOW VIKING', ship_type=<ShipType.Cargo: 70>, to_bow=75, to_stern=12, to_port=7, to_starboard=8, epfd=<EpfdType.GPS: 1>, month=11, day=22, hour=7, minute=0, draught=6.3, destination='SZCZECIN', dte=False, spare_1=b'\x00')
# ********************************************************************************
# MessageType18(msg_type=18, repeat=0, mmsi=257846700, reserved_1=0, speed=0.0, accuracy=True, lon=5.114115, lat=59.780502, course=336.0, heading=511, second=54, reserved_2=0, cs=True, display=False, dsc=True, band=True, msg22=True, assigned=False, raim=True, radio=917510)
# ********************************************************************************
# {'raw': b's:2573238,c:1732120734*02', 'receiver_timestamp': '1732120734', 'source_station': '2573238', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=565090000, status=<NavigationStatus.Moored: 5>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=False, lon=5.01572, lat=60.4157, course=167.0, heading=511, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=0)
# ********************************************************************************
# {'raw': b's:2573435,c:1732120734*09', 'receiver_timestamp': '1732120734', 'source_station': '2573435', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=257117920, reserved_1=0, speed=0.0, accuracy=False, lon=12.699183, lat=67.659345, course=360.0, heading=128, second=54, reserved_2=0, cs=False, display=False, dsc=True, band=True, msg22=True, assigned=False, raim=True, radio=610186)
# ********************************************************************************
# {'raw': b's:2573210,c:1732120734*08', 'receiver_timestamp': '1732120734', 'source_station': '2573210', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=258364000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=False, lon=5.948193, lat=59.183668, course=243.6, heading=307, second=52, maneuver=<ManeuverIndicator.NoSpecialManeuver: 1>, spare_1=b'\x00', raim=False, radio=100346)
# ********************************************************************************
# {'raw': b's:2573345,c:1732120734*09', 'receiver_timestamp': '1732120734', 'source_station': '2573345', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=258374500, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=3.0, speed=0.0, accuracy=True, lon=11.364753, lat=64.683557, course=170.5, heading=250, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=81954)
# ********************************************************************************
# {'raw': b's:2573525,c:1732120734*09', 'receiver_timestamp': '1732120734', 'source_station': '2573525', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257185420, status=<NavigationStatus.EngagedInFishing: 7>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=True, lon=18.603738, lat=69.392085, course=261.7, heading=511, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=34811)
# ********************************************************************************
# {'raw': b's:2573305,c:1732120734*0D', 'receiver_timestamp': '1732120734', 'source_station': '2573305', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=334928000, ais_version=2, imo=8422137, callsign='HQZT2', shipname='OLD WARRIOR', ship_type=<ShipType.Fishing: 30>, to_bow=24, to_stern=16, to_port=4, to_starboard=4, epfd=<EpfdType.Undefined: 0>, month=9, day=25, hour=9, minute=0, draught=4.5, destination='CH 16', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b'1G2:53625,s:2573225,c:1732120734*6B', 'receiver_timestamp': '1732120734', 'source_station': '2573225', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=304011027, ais_version=1, imo=9199256, callsign='V2OU', shipname='THESEUS', ship_type=<ShipType.Cargo: 70>, to_bow=76, to_stern=14, to_port=7, to_starboard=5, epfd=<EpfdType.GPS: 1>, month=11, day=12, hour=5, minute=10, draught=4.5, destination='NOSAS', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573525,c:1732120734*09', 'receiver_timestamp': '1732120734', 'source_station': '2573525', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257090430, status=<NavigationStatus.EngagedInFishing: 7>, turn=0.0, speed=7.4, accuracy=True, lon=16.933117, lat=69.941272, course=54.3, heading=51, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=100348)
# ********************************************************************************
# MessageType3(msg_type=3, repeat=0, mmsi=258334000, status=<NavigationStatus.Moored: 5>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=False, lon=5.209297, lat=60.074187, course=40.3, heading=511, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=87290)
# ********************************************************************************
# {'raw': b's:2573236,c:1732120734*0C', 'receiver_timestamp': '1732120734', 'source_station': '2573236', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=258825000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=7.9, accuracy=False, lon=6.172012, lat=60.249707, course=28.6, heading=29, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=49189)
# ********************************************************************************
# {'raw': b's:2573245,c:1732120734*08', 'receiver_timestamp': '1732120734', 'source_station': '2573245', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=258895000, ais_version=1, imo=9643465, callsign='LDAD', shipname='NORTH POMOR', ship_type=<ShipType.Cargo: 70>, to_bow=12, to_stern=80, to_port=13, to_starboard=7, epfd=<EpfdType.GPS_GLONASS: 3>, month=11, day=20, hour=4, minute=0, draught=5.7, destination='MONGSTAD', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573345,c:1732120734*09', 'receiver_timestamp': '1732120734', 'source_station': '2573345', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257475500, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=7.8, accuracy=False, lon=11.331163, lat=64.89367, course=44.7, heading=45, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=100352)
# ********************************************************************************
# {'raw': b's:2573238,c:1732120734*02', 'receiver_timestamp': '1732120734', 'source_station': '2573238', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=259526000, status=<NavigationStatus.Moored: 5>, turn=0.0, speed=0.0, accuracy=False, lon=5.266885, lat=59.81984, course=316.6, heading=141, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=84346)
# ********************************************************************************
# {'raw': b's:2573305,c:1732120734*0D', 'receiver_timestamp': '1732120734', 'source_station': '2573305', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=257106000, ais_version=1, imo=9252515, callsign='JXRX', shipname='KARINE H', ship_type=<ShipType.Fishing: 30>, to_bow=27, to_stern=43, to_port=8, to_starboard=8, epfd=<EpfdType.GPS: 1>, month=10, day=23, hour=6, minute=0, draught=7.8, destination='TROMSOE', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573335,c:1732120734*0E', 'receiver_timestamp': '1732120734', 'source_station': '2573335', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=314261000, status=<NavigationStatus.Moored: 5>, turn=0.0, speed=0.0, accuracy=False, lon=9.639825, lat=63.816993, course=341.0, heading=267, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=85162)
# ********************************************************************************
# {'raw': b's:2573305,c:1732120734*0D', 'receiver_timestamp': '1732120734', 'source_station': '2573305', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=314237000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=8.4, accuracy=True, lon=4.9079, lat=62.310783, course=21.3, heading=26, second=52, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=34822)
# ********************************************************************************
# {'raw': b's:2573210,c:1732120734*08', 'receiver_timestamp': '1732120734', 'source_station': '2573210', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=259216000, ais_version=1, imo=9344760, callsign='LIAT', shipname='MASTRAFJORD', ship_type=<ShipType.Passenger: 60>, to_bow=66, to_stern=63, to_port=10, to_starboard=9, epfd=<EpfdType.GPS: 1>, month=3, day=21, hour=12, minute=34, draught=0.0, destination='BOKNAFJORDEN', dte=False, spare_1=b'\x00')
# ********************************************************************************
# MessageType1(msg_type=1, repeat=1, mmsi=257785000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_RIGHT: 127.0>, speed=11.1, accuracy=False, lon=14.613245, lat=76.297503, course=341.2, heading=339, second=55, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=0)
# ********************************************************************************
# {'raw': b's:2573515,c:1732120734*0A', 'receiver_timestamp': '1732120734', 'source_station': '2573515', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=259009170, partno=0, shipname='LILLEOY', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573243,c:1732120734*0E', 'receiver_timestamp': '1732120734', 'source_station': '2573243', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=257107510, status=<NavigationStatus.Moored: 5>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=True, lon=5.264317, lat=60.746588, course=8.2, heading=511, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=86794)
# ********************************************************************************
# {'raw': b's:2573525,c:1732120734*09', 'receiver_timestamp': '1732120734', 'source_station': '2573525', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=257029690, reserved_1=0, speed=0.0, accuracy=True, lon=18.156583, lat=69.39744, course=19.1, heading=511, second=54, reserved_2=0, cs=True, display=False, dsc=True, band=True, msg22=True, assigned=False, raim=True, radio=917510)
# ********************************************************************************
# {'raw': b's:2573315,c:1732120734*0C', 'receiver_timestamp': '1732120734', 'source_station': '2573315', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=259206000, reserved_1=0, speed=0.0, accuracy=True, lon=8.212157, lat=63.144298, course=347.7, heading=511, second=54, reserved_2=0, cs=True, display=False, dsc=True, band=True, msg22=True, assigned=False, raim=True, radio=917510)
# ********************************************************************************
# MessageType5(msg_type=5, repeat=0, mmsi=258020030, ais_version=2, imo=0, callsign='LGTR', shipname='AMB AUSTEVOLLJENTA', ship_type=<ShipType.MedicalTransport: 58>, to_bow=9, to_stern=14, to_port=4, to_starboard=4, epfd=<EpfdType.GPS_GLONASS: 3>, month=3, day=21, hour=12, minute=34, draught=2.0, destination='AMBULANCE AUSTEVOLL', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573335,c:1732120734*0E', 'receiver_timestamp': '1732120734', 'source_station': '2573335', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=257512500, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=True, lon=8.826695, lat=63.758803, course=360.0, heading=511, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=85402)
# ********************************************************************************
# {'raw': b's:2573236,c:1732120734*0C', 'receiver_timestamp': '1732120734', 'source_station': '2573236', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=309186000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=10.2, accuracy=True, lon=6.090653, lat=60.135825, course=354.1, heading=352, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=2267)
# ********************************************************************************
# {'raw': b's:2573415,c:1732120735*0A', 'receiver_timestamp': '1732120735', 'source_station': '2573415', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=257079380, status=<NavigationStatus.Moored: 5>, turn=0.0, speed=0.0, accuracy=True, lon=13.060782, lat=66.661737, course=193.7, heading=37, second=55, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=85850)
# ********************************************************************************
# {'raw': b's:2573445,c:1732120735*0F', 'receiver_timestamp': '1732120735', 'source_station': '2573445', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257837000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=-2.0, speed=14.6, accuracy=True, lon=16.019393, lat=68.329993, course=1.9, heading=5, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=81968)
# ********************************************************************************
# {'raw': b's:2573105,c:1732120735*0E', 'receiver_timestamp': '1732120735', 'source_station': '2573105', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257064270, status=<NavigationStatus.Undefined: 15>, turn=0.0, speed=0.0, accuracy=False, lon=10.46518, lat=59.428367, course=118.2, heading=21, second=53, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=155800)
# ********************************************************************************
# MessageType24PartA(msg_type=24, repeat=0, mmsi=257055500, partno=0, shipname='HAUK', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573435,c:1732120735*08', 'receiver_timestamp': '1732120735', 'source_station': '2573435', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257418000, status=<NavigationStatus.EngagedInFishing: 7>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=False, lon=12.720177, lat=67.65407, course=360.0, heading=511, second=55, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=34839)
# ********************************************************************************
# {'raw': b's:2573213,c:1732120735*0A', 'receiver_timestamp': '1732120735', 'source_station': '2573213', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=259460000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=False, lon=5.265103, lat=59.413972, course=6.2, heading=324, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=34842)
# ********************************************************************************
# {'raw': b's:2573210,c:1732120735*09', 'receiver_timestamp': '1732120735', 'source_station': '2573210', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=992572500, ais_version=0, imo=0, callsign='LF8000', shipname='UNITECH ZEFYROS', ship_type=<ShipType.OtherType: 90>, to_bow=5, to_stern=4, to_port=5, to_starboard=4, epfd=<EpfdType.GPS: 1>, month=0, day=0, hour=24, minute=60, draught=25.5, destination='STATIONARY', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573345,c:1732120735*08', 'receiver_timestamp': '1732120735', 'source_station': '2573345', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=257106420, ais_version=2, imo=0, callsign='LH4065', shipname='SVANFJELL', ship_type=<ShipType.Cargo: 70>, to_bow=4, to_stern=7, to_port=3, to_starboard=3, epfd=<EpfdType.Internal_GNSS: 15>, month=0, day=0, hour=0, minute=0, draught=2.0, destination='VEDOYA', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573515,c:1732120735*0B', 'receiver_timestamp': '1732120735', 'source_station': '2573515', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=109080360, reserved_1=0, speed=1.4, accuracy=True, lon=16.673613, lat=69.716022, course=21.5, heading=511, second=60, reserved_2=0, cs=True, display=False, dsc=False, band=False, msg22=False, assigned=False, raim=False, radio=917510)
# ********************************************************************************
# MessageType5(msg_type=5, repeat=0, mmsi=257564000, ais_version=1, imo=9690949, callsign='LIER', shipname='POLARSYSSEL', ship_type=<ShipType.LawEnforcement: 55>, to_bow=23, to_stern=65, to_port=9, to_starboard=9, epfd=<EpfdType.GPS: 1>, month=3, day=21, hour=12, minute=34, draught=5.0, destination='CH1', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573515,c:1732120735*0B', 'receiver_timestamp': '1732120735', 'source_station': '2573515', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=109080360, partno=0, shipname='NORDAL 1       [93%]', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573308,c:1732120735*01', 'receiver_timestamp': '1732120735', 'source_station': '2573308', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType3(msg_type=3, repeat=0, mmsi=257087380, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_LEFT: -127.0>, speed=2.1, accuracy=True, lon=7.466518, lat=62.684718, course=290.9, heading=282, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=4144)
# ********************************************************************************
# {'raw': b's:2573105,c:1732120735*0E', 'receiver_timestamp': '1732120735', 'source_station': '2573105', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=257316340, reserved_1=0, speed=7.8, accuracy=False, lon=11.06266, lat=58.937108, course=95.7, heading=511, second=55, reserved_2=0, cs=True, display=False, dsc=True, band=True, msg22=True, assigned=False, raim=True, radio=917510)
# ********************************************************************************
# {'raw': b's:2573515,c:1732120735*0B', 'receiver_timestamp': '1732120735', 'source_station': '2573515', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=109080360, partno=1, ship_type=0, vendorid='RS', model=0, serial=1, callsign='', to_bow=0, to_stern=0, to_port=0, to_starboard=0, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573595,c:1732120735*03', 'receiver_timestamp': '1732120735', 'source_station': '2573595', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=257129140, reserved_1=0, speed=1.3, accuracy=True, lon=30.567892, lat=71.134832, course=206.8, heading=511, second=55, reserved_2=0, cs=True, display=False, dsc=True, band=True, msg22=True, assigned=False, raim=True, radio=917510)
# ********************************************************************************
# {'raw': b's:2573540,c:1732120735*0B', 'receiver_timestamp': '1732120735', 'source_station': '2573540', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=257137640, reserved_1=0, speed=10.8, accuracy=True, lon=19.105683, lat=70.397915, course=143.6, heading=511, second=55, reserved_2=0, cs=True, display=False, dsc=True, band=True, msg22=True, assigned=False, raim=True, radio=917510)
# ********************************************************************************
# {'raw': b's:2573335,c:1732120735*0F', 'receiver_timestamp': '1732120735', 'source_station': '2573335', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257077970, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=False, lon=10.124602, lat=64.183735, course=319.0, heading=224, second=54, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=24728)
# ********************************************************************************
# {'raw': b's:2573415,c:1732120735*0A', 'receiver_timestamp': '1732120735', 'source_station': '2573415', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=259032530, ais_version=2, imo=0, callsign='LH5693', shipname='HYBRID FOUR', ship_type=<ShipType.OtherType_NoAdditionalInformation: 99>, to_bow=10, to_stern=5, to_port=4, to_starboard=5, epfd=<EpfdType.GPS_GLONASS: 3>, month=8, day=16, hour=11, minute=0, draught=0.0, destination='LOVUND', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573936,c:1732120735*06', 'receiver_timestamp': '1732120735', 'source_station': '2573936', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# ...
# ********************************************************************************
# {'raw': b's:2573560,c:1732120750*0A', 'receiver_timestamp': '1732120750', 'source_station': '2573560', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=1234567, partno=0, shipname='CARINA 1', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573465,c:1732120750*0E', 'receiver_timestamp': '1732120750', 'source_station': '2573465', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=109080346, reserved_1=0, speed=0.5, accuracy=True, lon=14.912645, lat=68.07875, course=4.1, heading=511, second=60, reserved_2=0, cs=True, display=False, dsc=False, band=False, msg22=False, assigned=False, raim=False, radio=917510)
# ********************************************************************************
# {'raw': b's:2573560,c:1732120750*0A', 'receiver_timestamp': '1732120750', 'source_station': '2573560', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=1234567, partno=1, ship_type=0, vendorid='RS', model=0, serial=32961, callsign='BO1245', to_bow=85, to_stern=8, to_port=0, to_starboard=0, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573405,c:1732120750*08', 'receiver_timestamp': '1732120750', 'source_station': '2573405', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=259019220, partno=0, shipname='POLITI NORDLAND 1', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573450,c:1732120750*08', 'receiver_timestamp': '1732120750', 'source_station': '2573450', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=109080346, partno=0, shipname='ARIADNE 1      [88%]', spare_1=None)
# ********************************************************************************
# MessageType24PartA(msg_type=24, repeat=0, mmsi=258519810, partno=0, shipname='SEA MORE', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573555,c:1732120750*0C', 'receiver_timestamp': '1732120750', 'source_station': '2573555', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=257084240, partno=0, shipname='OEYFJORD', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573415,c:1732120750*09', 'receiver_timestamp': '1732120750', 'source_station': '2573415', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=258013980, reserved_1=0, speed=0.0, accuracy=False, lon=13.017473, lat=66.50923, course=360.0, heading=511, second=10, reserved_2=0, cs=False, display=False, dsc=True, band=True, msg22=True, assigned=False, raim=False, radio=619578)
# ********************************************************************************
# {'raw': b's:2573450,c:1732120750*08', 'receiver_timestamp': '1732120750', 'source_station': '2573450', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=109080346, partno=1, ship_type=0, vendorid='RS', model=0, serial=1, callsign='', to_bow=0, to_stern=0, to_port=0, to_starboard=0, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573345,c:1732120750*0B', 'receiver_timestamp': '1732120750', 'source_station': '2573345', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=257994700, partno=1, ship_type=70, vendorid='SMT', model=1, serial=694598, callsign='LG5576', to_bow=8, to_stern=2, to_port=2, to_starboard=2, spare_1=b'\xf0')
# ********************************************************************************
# {'raw': b's:2573335,c:1732120750*0C', 'receiver_timestamp': '1732120750', 'source_station': '2573335', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType8(msg_type=8, repeat=0, mmsi=257056610, spare_1=b'\x00', dac=200, fid=10, data=b'\xc3\x0c0\xc3\x0c0\x03@^\xfa\x05\x00\x00\x00')
# ********************************************************************************
# MessageType24PartB(msg_type=24, repeat=0, mmsi=258519810, partno=1, ship_type=60, vendorid='AMC', model=0, serial=95001, callsign='LG2540', to_bow=12, to_stern=3, to_port=2, to_starboard=3, spare_1=b'\xf0')
# ********************************************************************************
# {'raw': b's:2573455,c:1732120750*0D', 'receiver_timestamp': '1732120750', 'source_station': '2573455', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=982570105, partno=1, ship_type=59, vendorid='AMC', model=0, serial=95001, callsign='LCMO', to_bow=5, to_stern=1, to_port=1, to_starboard=1, spare_1=b'\xf0')
# ********************************************************************************
# {'raw': b's:2573135,c:1732120750*0E', 'receiver_timestamp': '1732120750', 'source_station': '2573135', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=334893000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=13.5, accuracy=True, lon=8.207332, lat=57.422152, course=62.3, heading=58, second=11, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=65945)
# ********************************************************************************
# {'raw': b's:2573545,c:1732120750*0D', 'receiver_timestamp': '1732120750', 'source_station': '2573545', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257194000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_RIGHT: 127.0>, speed=0.7, accuracy=True, lon=19.854017, lat=70.053353, course=136.8, heading=115, second=9, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=24732)
# ********************************************************************************
# {'raw': b's:2573405,c:1732120751*09', 'receiver_timestamp': '1732120751', 'source_station': '2573405', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257903800, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.1, accuracy=True, lon=12.859025, lat=66.23594, course=360.0, heading=511, second=10, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=24732)
# ********************************************************************************
# {'raw': b's:2573485,c:1732120751*01', 'receiver_timestamp': '1732120751', 'source_station': '2573485', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257080810, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=1.0, speed=0.0, accuracy=False, lon=17.335573, lat=68.723923, course=258.5, heading=335, second=10, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=24732)
# ********************************************************************************
# {'raw': b's:2573267,c:1732120751*0B', 'receiver_timestamp': '1732120751', 'source_station': '2573267', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=273411440, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=-8.0, speed=8.3, accuracy=True, lon=4.22222, lat=61.825972, course=205.2, heading=205, second=9, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=49196)
# ********************************************************************************
# {'raw': b's:2573315,c:1732120751*0F', 'receiver_timestamp': '1732120751', 'source_station': '2573315', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType5(msg_type=5, repeat=0, mmsi=257502700, ais_version=2, imo=0, callsign='LG7546', shipname='MADELEINE', ship_type=<ShipType.OtherType: 90>, to_bow=3, to_stern=12, to_port=4, to_starboard=4, epfd=<EpfdType.GPS: 1>, month=0, day=0, hour=0, minute=0, draught=0.0, destination='', dte=False, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573238,c:1732120751*01', 'receiver_timestamp': '1732120751', 'source_station': '2573238', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257083200, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=3.0, speed=1.8, accuracy=False, lon=5.218672, lat=60.335338, course=8.1, heading=10, second=10, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=81993)
# ********************************************************************************
# {'raw': b's:2573305,c:1732120751*0E', 'receiver_timestamp': '1732120751', 'source_station': '2573305', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=563101700, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_LEFT: -127.0>, speed=12.8, accuracy=True, lon=6.43462, lat=63.105092, course=76.7, heading=77, second=6, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=2220)
# ********************************************************************************
# {'raw': b's:2573145,c:1732120751*08', 'receiver_timestamp': '1732120751', 'source_station': '2573145', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartA(msg_type=24, repeat=0, mmsi=586706059, partno=0, shipname='NESEGUTTEN BOUY', spare_1=None)
# ********************************************************************************
# {'raw': b's:2573115,c:1732120751*0D', 'receiver_timestamp': '1732120751', 'source_station': '2573115', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257125930, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.1, accuracy=True, lon=9.697857, lat=59.051307, course=23.6, heading=67, second=11, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=24732)
# ********************************************************************************
# MessageType24PartB(msg_type=24, repeat=0, mmsi=106000126, partno=1, ship_type=0, vendorid='RS', model=0, serial=1, callsign='BO12345', to_bow=85, to_stern=0, to_port=0, to_starboard=0, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573577,c:1732120751*0D', 'receiver_timestamp': '1732120751', 'source_station': '2573577', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=259028270, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=True, lon=27.227277, lat=70.898032, course=234.0, heading=178, second=16, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=33185)
# ********************************************************************************
# MessageType3(msg_type=3, repeat=0, mmsi=257095330, status=<NavigationStatus.Moored: 5>, turn=0.0, speed=0.0, accuracy=False, lon=5.315, lat=59.283633, course=172.6, heading=262, second=10, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=78794)
# ********************************************************************************
# MessageType1(msg_type=1, repeat=0, mmsi=257215000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=True, lon=5.21423, lat=60.218502, course=202.3, heading=319, second=9, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=33187)
# ********************************************************************************
# {'raw': b's:2573145,c:1732120751*08', 'receiver_timestamp': '1732120751', 'source_station': '2573145', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType24PartB(msg_type=24, repeat=0, mmsi=586706059, partno=1, ship_type=0, vendorid='RS', model=0, serial=97, callsign='', to_bow=0, to_stern=0, to_port=0, to_starboard=0, spare_1=b'\x00')
# ********************************************************************************
# {'raw': b's:2573555,c:1732120751*0D', 'receiver_timestamp': '1732120751', 'source_station': '2573555', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType18(msg_type=18, repeat=0, mmsi=257071340, reserved_1=0, speed=2.3, accuracy=False, lon=21.139122, lat=70.419105, course=97.6, heading=511, second=11, reserved_2=0, cs=False, display=False, dsc=True, band=True, msg22=True, assigned=False, raim=False, radio=2363)
# ********************************************************************************
# {'raw': b's:2573525,c:1732120751*0A', 'receiver_timestamp': '1732120751', 'source_station': '2573525', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257531600, status=<NavigationStatus.Undefined: 15>, turn=0.0, speed=0.0, accuracy=False, lon=17.664987, lat=69.544292, course=59.4, heading=172, second=12, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=49176)
# ********************************************************************************
# {'raw': b's:2573105,c:1732120751*0C', 'receiver_timestamp': '1732120751', 'source_station': '2573105', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257054700, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=0.0, accuracy=False, lon=10.316508, lat=59.491213, course=360.0, heading=341, second=11, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=True, radio=2187)
# ********************************************************************************
# {'raw': b's:2573405,c:1732120751*09', 'receiver_timestamp': '1732120751', 'source_station': '2573405', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=259119000, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=0.0, speed=7.9, accuracy=False, lon=12.180763, lat=66.338962, course=109.9, heading=107, second=11, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=2212)
# ********************************************************************************
# {'raw': b's:2573253,c:1732120751*0C', 'receiver_timestamp': '1732120751', 'source_station': '2573253', 'destination_station': None, 'line_count': None, 'relative_time': None, 'text': None}
# MessageType1(msg_type=1, repeat=0, mmsi=257090140, status=<NavigationStatus.UnderWayUsingEngine: 0>, turn=<TurnRate.NO_TI_DEFAULT: -128.0>, speed=0.0, accuracy=False, lon=5.127863, lat=61.837453, course=246.5, heading=511, second=10, maneuver=<ManeuverIndicator.NotAvailable: 0>, spare_1=b'\x00', raim=False, radio=33191)
# 694

# %% [markdown]
# # Inspection of the norvegian feed and determine the fields for the messages types
# Watch out the feed goes forever if not stop with keyboard.

# %%
first = ddict(bool)
host = '153.44.253.27'
port = 5631
start = time.time()
try:
    for msg in TCPConnection(host, port=port):
        decoded_message = msg.decode()
        ais_content = decoded_message
        ais_content = ais_content.asdict()

        if msg.tag_block:
            # decode & print the tag block if it is available
            msg.tag_block.init()
            # writer.writerow({'first_name': 'Wonderful', 'last_name': 'Spam'})
            tag_block = msg.tag_block.asdict()
            ais_content['receiver_timestamp'] = tag_block['receiver_timestamp']
        if not first[ais_content['msg_type']]:
            print(ais_content['msg_type'], list(ais_content.keys()))
            first[ais_content['msg_type']] = True
except KeyboardInterrupt:
    pass
# Out:
# 24 ['msg_type', 'repeat', 'mmsi', 'partno', 'shipname', 'spare_1', 'receiver_timestamp']
# 3 ['msg_type', 'repeat', 'mmsi', 'status', 'turn', 'speed', 'accuracy', 'lon', 'lat', 'course', 'heading', 'second', 'maneuver', 'spare_1', 'raim', 'radio', 'receiver_timestamp']
# 5 ['msg_type', 'repeat', 'mmsi', 'ais_version', 'imo', 'callsign', 'shipname', 'ship_type', 'to_bow', 'to_stern', 'to_port', 'to_starboard', 'epfd', 'month', 'day', 'hour', 'minute', 'draught', 'destination', 'dte', 'spare_1', 'receiver_timestamp']
# 1 ['msg_type', 'repeat', 'mmsi', 'status', 'turn', 'speed', 'accuracy', 'lon', 'lat', 'course', 'heading', 'second', 'maneuver', 'spare_1', 'raim', 'radio', 'receiver_timestamp']
# 8 ['msg_type', 'repeat', 'mmsi', 'spare_1', 'dac', 'fid', 'data', 'receiver_timestamp']
# 18 ['msg_type', 'repeat', 'mmsi', 'reserved_1', 'speed', 'accuracy', 'lon', 'lat', 'course', 'heading', 'second', 'reserved_2', 'cs', 'display', 'dsc', 'band', 'msg22', 'assigned', 'raim', 'radio', 'receiver_timestamp']
# 21 ['msg_type', 'repeat', 'mmsi', 'aid_type', 'name', 'accuracy', 'lon', 'lat', 'to_bow', 'to_stern', 'to_port', 'to_starboard', 'epfd', 'second', 'off_position', 'reserved_1', 'raim', 'virtual_aid', 'assigned', 'spare_1', 'name_ext', 'receiver_timestamp']

# %% [markdown]
# # With the previous message field description, we save 20 minute of the norvegian coast guard feed.

# %%
recording_time = 20  # in minute
msg_type = [24, 3, 1, 5, 21, 18, 19, 8]
first = ddict(bool)
msg_columns = {1 : ['msg_type', 'receiver_timestamp', 'repeat', 'mmsi', 'status', 'turn', 'speed', 'accuracy', 'lon', 'lat', 'course', 'heading', 'second', 'maneuver', 'spare_1', 'raim', 'radio'],
               3 : ['msg_type', 'receiver_timestamp', 'repeat', 'mmsi', 'status', 'turn', 'speed', 'accuracy', 'lon', 'lat', 'course', 'heading', 'second', 'maneuver', 'spare_1', 'raim', 'radio'],
               5 : ['msg_type', 'receiver_timestamp', 'repeat', 'mmsi', 'ais_version', 'imo', 'callsign', 'shipname', 'ship_type', 'to_bow', 'to_stern', 'to_port', 'to_starboard', 'epfd', 'month', 'day', 'hour', 'minute', 'draught', 'destination', 'dte', 'spare_1'],
               8 : ['msg_type', 'receiver_timestamp', 'repeat', 'mmsi', 'spare_1', 'dac', 'fid', 'data'],
               18 : ['msg_type', 'receiver_timestamp', 'repeat', 'mmsi', 'reserved_1', 'speed', 'accuracy', 'lon', 'lat', 'course', 'heading', 'second', 'reserved_2', 'cs', 'display', 'dsc', 'band', 'msg22', 'assigned', 'raim', 'radio'],
               19 : ['msg_type', 'receiver_timestamp', 'repeat', 'mmsi', 'reserved_1', 'speed', 'accuracy', 'lon', 'lat', 'course', 'heading', 'second', 'reserved_2', 'shipname', 'ship_type', 'to_bow', 'to_stern', 'to_port', 'to_starboard', 'epfd', 'raim', 'dte', 'assigned', 'spare_1'],
               21 : ['msg_type', 'receiver_timestamp', 'repeat', 'mmsi', 'aid_type', 'name', 'accuracy', 'lon', 'lat', 'to_bow', 'to_stern', 'to_port', 'to_starboard', 'epfd', 'second', 'off_position', 'reserved_1', 'raim', 'virtual_aid', 'assigned', 'spare_1', 'name_ext'],
               24 : ['msg_type', 'receiver_timestamp', 'repeat', 'mmsi', 'partno', 'shipname', 'spare_1', 'to_starboard', 'callsign', 'serial', 'ship_type', 'model', 'vendorid', 'to_port', 'to_bow', 'to_stern']}

with ExitStack() as stack:   # allows for multiple with open statement on two lines
    # open n files for each message type: 1, 3, 5, 8, 18, 19, 21 et 24
    files = {n : stack.enter_context(open(f"data/norvegian_20_min/message_{n}.csv", 'w', newline='')) for n in msg_type}
    csv_writers = {n : csv.DictWriter(file, msg_columns[n]) for n, file in files.items()}
    
    host = '153.44.253.27'
    port = 5631
    start = time.time()
    
    for msg in TCPConnection(host, port=port):
        decoded_message = msg.decode()
        ais_content = decoded_message
        ais_content = ais_content.asdict()

        if msg.tag_block:
            msg.tag_block.init()
            tag_block = msg.tag_block.asdict()
            ais_content['receiver_timestamp'] = tag_block['receiver_timestamp']

        writer = csv_writers[ais_content['msg_type']]   # select csv_writer to file that correspond to the msg_type
        if not first[ais_content['msg_type']]:   # If first message of that msg_type, then write the header of the file.
            writer.writeheader()
            first[ais_content['msg_type']] = True
        try:
            writer.writerow(ais_content)
        except ValueError as e:
            print(e, f"    msg_type: {ais_content['msg_type']}")
            break

        if time.time() > start + (recording_time * 60):   # stop recording after N minutes.
            break
